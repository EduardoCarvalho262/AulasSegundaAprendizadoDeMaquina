# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoCarvalho262/AulasSegundaAprendizadoDeMaquina/blob/main/AtividadeDia04_03_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
P = True
Q = False
R = False

# %%
resultado = P and Q or (not(P) and R)

# %%
resultado

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
P = False
Q = True
R = False

# %%
resultado = P or (Q and R) or R

# %%
print(resultado)
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
P = True
Q = False
R = True

# %%
resultado = (not(P) and R)

# %%
if P:
  print(Q or resultado)
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
P = True
Q = False
R = False

# %%
##resultado = (P and R) or (and R) - Não é possivel executar o algoritmo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
P = False
Q = True
R = False

# %%
##resultado = P or Q and (R) or R) - Sintax incorreta

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
P = True
Q = False
R = True

# %%
resultado = (P and Q or not(R))

# %%
if R:
  print(Q and resultado)
# Out:
# False
